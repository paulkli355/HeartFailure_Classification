# %%
import pandas as pd
import seaborn as sns
from summarytools import dfSummary
import matplotlib.pyplot as plt

# %%
heart_df = pd.read_csv('data/heart.csv')
heart_df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
dfSummary(heart_df)
# Out:
# <style type="text/css">
# #T_3f32b thead>tr>th {
#   text-align: left;
# }
# #T_3f32b_row0_col0, #T_3f32b_row1_col0, #T_3f32b_row2_col0, #T_3f32b_row3_col0, #T_3f32b_row4_col0, #T_3f32b_row5_col0, #T_3f32b_row6_col0, #T_3f32b_row7_col0, #T_3f32b_row8_col0, #T_3f32b_row9_col0, #T_3f32b_row10_col0, #T_3f32b_row11_col0, #T_3f32b_row12_col0, #T_3f32b_row13_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_3f32b_row0_col1, #T_3f32b_row1_col1, #T_3f32b_row2_col1, #T_3f32b_row3_col1, #T_3f32b_row4_col1, #T_3f32b_row5_col1, #T_3f32b_row6_col1, #T_3f32b_row7_col1, #T_3f32b_row8_col1, #T_3f32b_row9_col1, #T_3f32b_row10_col1, #T_3f32b_row11_col1, #T_3f32b_row12_col1, #T_3f32b_row13_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_3f32b_row0_col2, #T_3f32b_row1_col2, #T_3f32b_row2_col2, #T_3f32b_row3_col2, #T_3f32b_row4_col2, #T_3f32b_row5_col2, #T_3f32b_row6_col2, #T_3f32b_row7_col2, #T_3f32b_row8_col2, #T_3f32b_row9_col2, #T_3f32b_row10_col2, #T_3f32b_row11_col2, #T_3f32b_row12_col2, #T_3f32b_row13_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_3f32b_row0_col3, #T_3f32b_row1_col3, #T_3f32b_row2_col3, #T_3f32b_row3_col3, #T_3f32b_row4_col3, #T_3f32b_row5_col3, #T_3f32b_row6_col3, #T_3f32b_row7_col3, #T_3f32b_row8_col3, #T_3f32b_row9_col3, #T_3f32b_row10_col3, #T_3f32b_row11_col3, #T_3f32b_row12_col3, #T_3f32b_row13_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_3f32b_row0_col4, #T_3f32b_row1_col4, #T_3f32b_row2_col4, #T_3f32b_row3_col4, #T_3f32b_row4_col4, #T_3f32b_row5_col4, #T_3f32b_row6_col4, #T_3f32b_row7_col4, #T_3f32b_row8_col4, #T_3f32b_row9_col4, #T_3f32b_row10_col4, #T_3f32b_row11_col4, #T_3f32b_row12_col4, #T_3f32b_row13_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_3f32b_row0_col5, #T_3f32b_row1_col5, #T_3f32b_row2_col5, #T_3f32b_row3_col5, #T_3f32b_row4_col5, #T_3f32b_row5_col5, #T_3f32b_row6_col5, #T_3f32b_row7_col5, #T_3f32b_row8_col5, #T_3f32b_row9_col5, #T_3f32b_row10_col5, #T_3f32b_row11_col5, #T_3f32b_row12_col5, #T_3f32b_row13_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_3f32b">
#   <caption><strong>Data Frame Summary</strong><br>heart_df<br>Dimensions: 1,025 x 14<br>Duplicates: 723</caption>
#   <thead>
#     <tr>
#       <th id="T_3f32b_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_3f32b_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_3f32b_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_3f32b_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_3f32b_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_3f32b_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3f32b_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_3f32b_row0_col1" class="data row0 col1" ><strong>age</strong><br>[int64]</td>
#       <td id="T_3f32b_row0_col2" class="data row0 col2" >Mean (sd) : 54.4 (9.1)<br>min < med < max:<br>29.0 < 56.0 < 77.0<br>IQR (CV) : 13.0 (6.0)</td>
#       <td id="T_3f32b_row0_col3" class="data row0 col3" >41 distinct values</td>
#       <td id="T_3f32b_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_3f32b_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_3f32b_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_3f32b_row1_col1" class="data row1 col1" ><strong>sex</strong><br>[int64]</td>
#       <td id="T_3f32b_row1_col2" class="data row1 col2" >Mean (sd) : 0.7 (0.5)<br>min < med < max:<br>0.0 < 1.0 < 1.0<br>IQR (CV) : 1.0 (1.5)</td>
#       <td id="T_3f32b_row1_col3" class="data row1 col3" >2 distinct values</td>
#       <td id="T_3f32b_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_3f32b_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_3f32b_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_3f32b_row2_col1" class="data row2 col1" ><strong>cp</strong><br>[int64]</td>
#       <td id="T_3f32b_row2_col2" class="data row2 col2" >Mean (sd) : 0.9 (1.0)<br>min < med < max:<br>0.0 < 1.0 < 3.0<br>IQR (CV) : 2.0 (0.9)</td>
#       <td id="T_3f32b_row2_col3" class="data row2 col3" >4 distinct values</td>
#       <td id="T_3f32b_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_3f32b_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_3f32b_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_3f32b_row3_col1" class="data row3 col1" ><strong>trestbps</strong><br>[int64]</td>
#       <td id="T_3f32b_row3_col2" class="data row3 col2" >Mean (sd) : 131.6 (17.5)<br>min < med < max:<br>94.0 < 130.0 < 200.0<br>IQR (CV) : 20.0 (7.5)</td>
#       <td id="T_3f32b_row3_col3" class="data row3 col3" >49 distinct values</td>
#       <td id="T_3f32b_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_3f32b_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_3f32b_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_3f32b_row4_col1" class="data row4 col1" ><strong>chol</strong><br>[int64]</td>
#       <td id="T_3f32b_row4_col2" class="data row4 col2" >Mean (sd) : 246.0 (51.6)<br>min < med < max:<br>126.0 < 240.0 < 564.0<br>IQR (CV) : 64.0 (4.8)</td>
#       <td id="T_3f32b_row4_col3" class="data row4 col3" >152 distinct values</td>
#       <td id="T_3f32b_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_3f32b_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_3f32b_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_3f32b_row5_col1" class="data row5 col1" ><strong>fbs</strong><br>[int64]</td>
#       <td id="T_3f32b_row5_col2" class="data row5 col2" >Mean (sd) : 0.1 (0.4)<br>min < med < max:<br>0.0 < 0.0 < 1.0<br>IQR (CV) : 0.0 (0.4)</td>
#       <td id="T_3f32b_row5_col3" class="data row5 col3" >2 distinct values</td>
#       <td id="T_3f32b_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_3f32b_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_3f32b_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_3f32b_row6_col1" class="data row6 col1" ><strong>restecg</strong><br>[int64]</td>
#       <td id="T_3f32b_row6_col2" class="data row6 col2" >Mean (sd) : 0.5 (0.5)<br>min < med < max:<br>0.0 < 1.0 < 2.0<br>IQR (CV) : 1.0 (1.0)</td>
#       <td id="T_3f32b_row6_col3" class="data row6 col3" >3 distinct values</td>
#       <td id="T_3f32b_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_3f32b_row6_col5" class="data row6 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_3f32b_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_3f32b_row7_col1" class="data row7 col1" ><strong>thalach</strong><br>[int64]</td>
#       <td id="T_3f32b_row7_col2" class="data row7 col2" >Mean (sd) : 149.1 (23.0)<br>min < med < max:<br>71.0 < 152.0 < 202.0<br>IQR (CV) : 34.0 (6.5)</td>
#       <td id="T_3f32b_row7_col3" class="data row7 col3" >91 distinct values</td>
#       <td id="T_3f32b_row7_col4" class="data row7 col4" ><img src = "......"></img></td>
#       <td id="T_3f32b_row7_col5" class="data row7 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_3f32b_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_3f32b_row8_col1" class="data row8 col1" ><strong>exang</strong><br>[int64]</td>
#       <td id="T_3f32b_row8_col2" class="data row8 col2" >Mean (sd) : 0.3 (0.5)<br>min < med < max:<br>0.0 < 0.0 < 1.0<br>I

# %%
plt.pie(x=heart_df.target.value_counts().values,labels=heart_df.target.unique().tolist(),autopct='%1.2f%%')
plt.title('Target Distribution')
plt.show()

# %%
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
heart_df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# min       0.000000     0.000000    71.000000     0.000000     0.000000
# 25%       0.000000     0.000000   132.000000     0.000000     0.000000
# 50%       0.000000     1.000000   152.000000     0.000000     0.800000
# 75%       0.000000     1.000000   166.000000     1.000000     1.800000
# max       1.000000     2.000000   202.000000     1.000000     6.200000
#
#              slope           ca         thal       target
# count  1025.000000  1025.000000  1025.000000  1025.000000
# mean      1.385366     0.754146     2.323902     0.513171
# std       0.617755     1.030798     0.620660     0.500070
# min       0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     2.000000     0.000000
# 50%       1.000000     0.000000     2.000000     1.000000
# 75%       2.000000     1.000000     3.000000     1.000000
# max       2.000000     4.000000     3.000000     1.000000

# %%
print('Initial number of rows: ', heart_df.shape)
heart_df.drop_duplicates(inplace=True)
print('Number of rows after dropping duplicates: ', heart_df.shape)
# Out:
# Initial number of rows:  (1025, 14)
# Number of rows after dropping duplicates:  (302, 14)

# %%
corr_matrix = heart_df.corr()
f,ax=plt.subplots(figsize = (10,7))
sns.heatmap(corr_matrix, annot = True, fmt = ".2f", linewidths = .5,ax=ax)
# Out:
# <Axes: >

# %%
corr_matrix["target"].abs().nlargest(10)
# Out:
# target     1.000000
# exang      0.435601
# cp         0.432080
# oldpeak    0.429146
# thalach    0.419955
# ca         0.408992
# slope      0.343940
# thal       0.343101
# sex        0.283609
# age        0.221476
# Name: target, dtype: float64

# %%
heart_df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
t0 = heart_df[heart_df.target==0]
t1 = heart_df[heart_df.target==1]

sns.histplot(t0.age,kde=False,color="blue", label="Age for Heart Failure 0")
sns.histplot(t1.age,kde=False,color = "red", label = "Age for Heart Failure 1")
plt.title("Histograms for Age by Heart Failure")
plt.legend()

# %%
sns.boxplot(x='target', y='age', data=heart_df)
# Out:
# <Axes: xlabel='target', ylabel='age'>

# %%
sns.boxplot(x='target', y='age', hue='sex', data=heart_df)
# Out:
# <Axes: xlabel='target', ylabel='age'>

# %%
sns.catplot(x='target', y='age', hue='sex', kind='violin', data=heart_df)
# Out:
# c:\Users\pklimanek\Anaconda3\envs\mgr\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.histplot(t0.exang,kde=False,color="blue", label="exang for Heart Failure 0")
sns.histplot(t1.exang,kde=False,color = "red", label = "exang for Heart Failure 1")
plt.title("Histograms for exang by Heart Failure")
plt.legend()

# %%
sns.boxplot(x='target', y='exang', data=heart_df)
# Out:
# <Axes: xlabel='target', ylabel='exang'>

# %%
sns.boxplot(x='target', y='cp', data=heart_df)
# Out:
# <Axes: xlabel='target', ylabel='cp'>

# %%
sns.boxplot(x='target', y='oldpeak', data=heart_df)
# Out:
# <Axes: xlabel='target', ylabel='oldpeak'>

# %%
sns.set_style(style='darkgrid')
sns.pairplot(heart_df)
# Out:
# c:\Users\pklimanek\Anaconda3\envs\mgr\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# EDA ( Exploratory Data Analysis )
# Univariante
column=heart_df.columns
plt.figure(figsize=(22,25))
for i,col in enumerate(column,1):
    plt.subplot(4,4,i)
    
    try:
        plt.title(col)
        sns.kdeplot(data=heart_df,x=col)
    except:
        plt.title(col)
        sns.countplot(data=heart_df,x=col)
plt.show()

# %%
# check outliers
plt.figure(figsize=(17,21))
for i,col in enumerate(column,1):
    plt.subplot(4,4,i)
    sns.set_theme(style="whitegrid")
    
    try:
        plt.title(col)
        sns.boxplot(x=col,data=heart_df)
    except:
        plt.title(col)
        sns.boxplot(x=col,y='age',data=heart_df)
        
plt.show()

# %%
# Visualise relationship between sex and target column
pd.crosstab(heart_df.target, heart_df.sex).plot(kind="bar",
                                    figsize=(10, 6),
                                    color=["sandybrown", "violet"])

# Add details
plt.title("Heart Disease Frequency for Sex")
plt.ylabel("Amount")
plt.legend(["Male", "Female"]);
plt.xticks(rotation=0);

# %%
# Visualise Age vs Max Heart Rate for Heart Disease
plt.figure(figsize=(10, 6))

# Scatter with heart disease samples
plt.scatter(heart_df.age[heart_df.target==1],
            heart_df.thalach[heart_df.target==1],
            c="sandybrown")

# Scatter with non heart disease samples
plt.scatter(heart_df.age[heart_df.target==0],
            heart_df.thalach[heart_df.target==0],
            c="violet")

# Add details
plt.title("Heart Disease in function of Age and Max Heart Rate")
plt.xlabel("Age")
plt.ylabel("Max Heart Rate")
plt.legend(["Disease", "No Disease"]);
